# %%
import sympy as sp

# %%
def taylor(x):
    y = 0
    d1 = sp.diff(f, x)  # Перша похідна
    d2 = sp.diff(d1, x) # Друга похідна
    d3 = sp.diff(d2, x) # Третя похідна

    print(f'd1 = {d1}; d2 = {d2}; d3 = {d3}')

    y += f + d1*x + d2*x**2/2 + d3*x**3/6
    
    print(f'y = {y}')
    return y

# %%
x = sp.symbols('x')
f = sp.E ** sp.cos(x)
taylor_x = taylor(x)
sp.plot(taylor_x, f, (x, -2, 2))
# Out:
# d1 = -exp(cos(x))*sin(x); d2 = exp(cos(x))*sin(x)**2 - exp(cos(x))*cos(x); d3 = -exp(cos(x))*sin(x)**3 + 3*exp(cos(x))*sin(x)*cos(x) + exp(cos(x))*sin(x)
# y = x**3*(-exp(cos(x))*sin(x)**3 + 3*exp(cos(x))*sin(x)*cos(x) + exp(cos(x))*sin(x))/6 + x**2*(exp(cos(x))*sin(x)**2 - exp(cos(x))*cos(x))/2 - x*exp(cos(x))*sin(x) + exp(cos(x))
